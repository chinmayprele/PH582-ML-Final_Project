# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("../data/standard_data.csv")
df.sample(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 99   862548         M        14.42         19.77           94.48      642.5
# 402  904689         B        12.96         18.29           84.18      525.2
# 454  911202         B        12.62         17.15           80.62      492.9
# 313  893988         B        11.54         10.72           73.73      409.1
# 476  911654         B        14.20         20.53           92.41      618.4
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 99           0.09752           0.11410         0.09388             0.058390
# 402          0.07351           0.07899         0.04057             0.018830
# 454          0.08583           0.05430         0.02966             0.022720
# 313          0.08597           0.05969         0.01367             0.008907
# 476          0.08931           0.11080         0.05063             0.030580
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 99   ...          30.86           109.50       826.4           0.14310
# 402  ...          24.61            96.31       621.9           0.09329
# 454  ...          22.15            91.62       633.5           0.12250
# 313  ...          12.87            81.23       467.8           0.10920
# 476  ...          27.26           112.10       828.5           0.11530
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 99              0.3026          0.31940               0.15650          0.2718
# 402             0.2318          0.16040               0.06608          0.3207
# 454             0.1517          0.18870               0.09851          0.3270
# 313             0.1626          0.08324               0.04715          0.3390
# 476             0.3429          0.25120               0.13390          0.2534
#
#      fractal_dimension_worst  Unnamed: 32
# 99                   0.09353          NaN
# 402                  0.07247          NaN
# 454                  0.07330          NaN
# 313                  0.07434          NaN
# 476                  0.07858          NaN
#
# [5 rows x 33 columns]

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# Unnamed: 32                float64
# dtype: object

# %%
df.drop('id',axis='columns',inplace=True)

# %%
df.sample(2)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 142         B        11.43         17.31           73.66      398.0
# 443         B        10.57         18.32           66.82      340.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 142          0.10920           0.09486         0.02031              0.01861
# 443          0.08142           0.04462         0.01993              0.01111
#
#      symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 142         0.1645  ...          26.76            82.66       503.0
# 443         0.2372  ...          23.31            69.35       366.3
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 142           0.14130            0.17920          0.07708
# 443           0.09794            0.06542          0.03986
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 142               0.06402          0.2584                  0.08096
# 443               0.02222          0.2699                  0.06736
#
#      Unnamed: 32
# 142          NaN
# 443          NaN
#
# [2 rows x 32 columns]

# %%
df.drop('Unnamed: 32',axis='columns',inplace=True)

# %%
df.sample(2)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 554         B        12.88         28.92           82.50      514.3
# 150         B        13.00         20.78           83.51      519.4
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 554          0.08123           0.05824         0.06195              0.02343
# 150          0.11350           0.07589         0.03136              0.02645
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 554         0.1566  ...         13.89          35.74            88.84
# 150         0.2540  ...         14.16          24.11            90.82
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 554       595.7            0.1227             0.1620          0.24390
# 150       616.7            0.1297             0.1105          0.08112
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 554               0.06493          0.2372                  0.07242
# 150               0.06296          0.3196                  0.06435
#
# [2 rows x 31 columns]

# %%
cols_to_scale = ['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean',
                 'concavity_mean','concave points_mean','symmetry_mean', 'fractal_dimension_mean','radius_se',
                 'texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se',
                 'concave points_se','symmetry_se', 'fractal_dimension_se', 'radius_worst','texture_worst',
                 'perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst',
                 'symmetry_worst', 'fractal_dimension_worst']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df.sample(2)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 557         B     0.115576      0.614474        0.106903   0.054210
# 348         B     0.212457      0.213730        0.201990   0.109947
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 557         0.258193          0.093031        0.000000             0.000000
# 348         0.344227          0.121097        0.060614             0.115408
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 557       0.344444  ...      0.091071       0.592217         0.080133
# 348       0.289899  ...      0.162931       0.233742         0.145724
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 557    0.035735          0.238592           0.042970         0.000000
# 348    0.071422          0.541042           0.082186         0.078458
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 557              0.000000        0.179381                 0.096091
# 348              0.225017        0.253499                 0.213761
#
# [2 rows x 31 columns]

# %%
X = df.drop('diagnosis',axis='columns')
y = testLabels = df.diagnosis.astype(np.object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_train.value_counts()
# Out:
# B    290
# M    165
# Name: diagnosis, dtype: int64

# %%
y.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
len(X_train.columns)
# Out:
# 30

# %% [markdown]
# # Undersample

# %%
# Class count
count_class_B, count_class_M = df.diagnosis.value_counts()
print(count_class_B, count_class_M)

# Divide by class
df_class_M = df[df['diagnosis'] == 'M']
df_class_B = df[df['diagnosis'] == 'B']
# Out:
# 357 212

# %%
# Undersample 0-class and concat the DataFrames of both class
df_class_B_under = df_class_B.sample(count_class_M)
df_test_under = pd.concat([df_class_B_under, df_class_M], axis=0)

print('Random under-sampling:')
print(df_test_under.diagnosis.value_counts())
# Out:
# Random under-sampling:
# B    212
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# # Oversample

# %%
# Oversample M-class and concat the DataFrames of both classes
df_class_M_over = df_class_M.sample(count_class_B, replace=True)
df_test_over = pd.concat([df_class_M_over, df_class_B], axis=0)

print('Random over-sampling:')
print(df_test_over.diagnosis.value_counts())
# Out:
# Random over-sampling:
# M    357
# B    357
# Name: diagnosis, dtype: int64

# %% [markdown]
# # Ensemble with undersampling

# %%
X = df.drop('diagnosis',axis='columns')
y = df['diagnosis']

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df_test_over.to_csv('data_over.csv')

# %%
df_test_under.to_csv('data_under.csv')

# %% [markdown]
# EDA

# %%
bc = pd.read_csv("data_over.csv")
mean=bc.iloc[:,1:11]
se=bc.iloc[:,12:22]
worst=bc.iloc[:,22:]

# %%
mean.sample(2)
se.sample(2)
# Out:
#      radius_se  texture_se  perimeter_se   area_se  smoothness_se  \
# 209   0.232953    0.205048      0.216558  0.154909       0.213618
# 489   0.028571    0.037372      0.019177  0.011894       0.161777
#
#      compactness_se  concavity_se  concave points_se  symmetry_se  \
# 209        0.185868      0.094369           0.312180     0.296730
# 489        0.067354      0.032374           0.167626     0.127174
#
#      fractal_dimension_se
# 209              0.107140
# 489              0.066408

# %%
mean_histogram = mean.hist(bins=20, figsize=(15, 10),grid=False,)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-3adb4ee2987c> in <module>
# ----> 1 mean_histogram = mean.hist(bins=20, figsize=(15, 10),grid=False,)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     197         layout=layout,
#     198         bins=bins,
# --> 199         **kwds
#     200     )
#     201
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     404         sharey=sharey,
#     405         figsize=figsize,
# --> 406         layout=layout,
#     407     )
#     408     _axes = _flatten(axes)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     261             ax.set_visible(False)
#     262
# --> 263     _handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     264
#     265     if squeeze:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py in _handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     305                 layout = np.zeros((nrows + 1, ncols + 1), dtype=np.bool)
#     306                 for ax in axarr:
# --> 307                     layout[ax.rowNum, ax.colNum] = ax.get_visible()
#     308
#     309                 for ax in axarr:
#
# AttributeError: 'AxesSubplot' object has no attribute 'rowNum'

# %%
se_histogram = se.hist(bins=20, figsize=(15, 10),grid=False,)

# %%
worst_histogram = worst.hist(bins=20, figsize=(15, 10),grid=False,)

# %%
cor = mean.corr()

# %%
import seaborn as sn

sn.heatmap( cor, annot=True, fmt="d" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-80cf21e9c8b5> in <module>
#       1 import seaborn as sn
#       2
# ----> 3 sn.heatmap( cor, annot=True, fmt="d" )
#
# NameError: name 'cor' is not defined

# %%
g = sn.PairGrid(bc[[bc.columns[1],bc.columns[2],bc.columns[3],
                     bc.columns[4], bc.columns[5],bc.columns[6],bc.columns[7],bc.columns[8]]],hue='diagnosis' )
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter, s = 3)
